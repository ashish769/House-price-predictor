# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("home_prices.csv")
print(df)
# Out:
#     area   price
# 0    600   50000
# 1    750   65000
# 2    900   80000
# 3   1100  100000
# 4   1300  120000
# 5   1500  140000
# 6   1800  170000
# 7   2000  190000
# 8   2200  210000
# 9   2500  240000
# 10  2700  260000
# 11  3000  290000
# 12  3200  310000
# 13  3500  340000
# 14  3800  370000
# 15  4000  390000
# 16  4500  450000
# 17  5000  500000
# 18  5500  550000
# 19  6000  600000

# %%
# %matplotlib inline
plt.xlabel("Area in sq.ft")
plt.ylabel("price in $")
plt.scatter(df.area,df.price,color='red',marker='*')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')#to draw the best fit line

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
# Using DataFrame with column name
predicted_price = reg.predict(pd.DataFrame([[3300]], columns=['area'])) 
print(predicted_price)
# Out:
# [322998.31653622]

# %%
m=reg.coef_#slope 
x=3300#area of the house 
c=reg.intercept_#incept value 
y=m*x+c#price of the house
print(f'The price of the Area:{x}sq ft is ${y[0]}')
# Out:
# The price of the Area:3300sq ft is $322998.31653621694
